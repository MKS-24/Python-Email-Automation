# %% [markdown]
# # Python Email Automation
# # Date: 11th February 2025
# # Technologies Used: Python, Email.message, OS, Pandas

# %% [markdown]
# ##                                  -o) Import libraries

# %%
import pandas as pd
import smtplib
import os
from email.message import EmailMessage

# %% [markdown]
# ##                                  -o) Load dataset

# %%
# Read Excel File
df = pd.read_excel('E:/3_Python/100_DaysPython/0Emial/Excel.xlsx', engine="openpyxl")

# SMTP Server Configuration
SMTP_SERVER = "smtp.gmail.com"
SMTP_PORT = 587
SENDER_EMAIL = "muhammadkhuzaimasiddiqui@gmail.com"  # Sender Email
SENDER_PASSWORD = "xxxxxxxxxxxxxx"  # Gmail password


# Email Setup
for index, row in df.iterrows():
    receiver_email = row["Email"]
    invoice_path = row["Invoice"]

    # Check if invoice file exist
    if not os.path.exists(invoice_path):
        print(f"Error: File {invoice_path} not found. Skipping email to {receiver_email}")
        continue  # Agle student par move karein

    # Create Email Message
    msg = EmailMessage()
    msg["Subject"] = "Your Invoice"
    msg["From"] = SENDER_EMAIL
    msg["To"] = receiver_email
    msg.set_content(f"Dear {row['Name']},\n\nAttached is your invoice.\n\nBest regards,\nYour Company")

    # Attach Invoice  
    with open(invoice_path, "rb") as file:
        file_data = file.read()
        file_name = os.path.basename(invoice_path)  # Extract Only File Name  
        msg.add_attachment(file_data, maintype="image", subtype="png", filename=file_name)

    # Send Email By SMTP Server 
    try:
        with smtplib.SMTP(SMTP_SERVER, SMTP_PORT) as server:
            server.starttls()
            server.login(SENDER_EMAIL, SENDER_PASSWORD)
            server.send_message(msg)
        print(f"Email sent to {receiver_email} with invoice {file_name}")
    except Exception as e:
        print(f"Error sending email to {receiver_email}: {e}")
